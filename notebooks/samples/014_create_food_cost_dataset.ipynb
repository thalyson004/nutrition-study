# %%
import sys
sys.path.append("../..")
from pandas import DataFrame
import pandas as pd
import os

# %%
# datasetPath = os.path.dirname(os.path.abspath(__file__)) + "/../../../datasets/"
# datasetPicklePath = (
#     os.path.dirname(os.path.abspath(__file__)) + "/../../../datasets/pickle"
# )

datasetPath = os.getcwd() + "/../../datasets/"
datasetPicklePath = os.getcwd()  + "/../../datasets/pickle"

# %%
datasetPath
# Out:
# 'e:\\Projetos\\Doctorate\\nutrition-study\\notebooks\\samples/../../datasets/'

# %% [markdown]
# # Despesa Coletiva

# %%
wDespesaColetiva = [2,4,1,9,2,1,2,2,7,2,4,10,2,2,1,10,1,12,10,10,1,1,2,14,14,10,5]
hDespesaColetiva = ['UF',
   'ESTRATO_POF',
   'TIPO_SITUACAO_REG',
   'COD_UPA',
   'NUM_DOM',
   'NUM_UC',
   'QUADRO',
   'SEQ',
   'V9001',
   'V9002',
   'V9005',
   'V8000',
   'V9010',
   'V9011',
   'V9012',
   'V1904',
   'V1905',
   'DEFLATOR',
   'V8000_DEFLA',
   'V1904_DEFLA',
   'COD_IMPUT_VALOR',
   'COD_IMPUT_QUANTIDADE',
   'FATOR_ANUALIZACAO',
   'PESO',
   'PESO_FINAL',
   'RENDA_TOTAL',
   "V9004"]

dfDespesaColetiva = pd.read_fwf(f"{datasetPath}/despesa_coletiva.txt", widths=wDespesaColetiva, index=False, header=None, dtype=str)
dfDespesaColetiva.columns = hDespesaColetiva

# %%
dfDespesaColetiva
# Out:
#         UF ESTRATO_POF TIPO_SITUACAO_REG    COD_UPA NUM_DOM NUM_UC QUADRO SEQ
# 0       11        1103                 1  110005400       1      1      6   0  \
# 1       11        1103                 1  110005400       1      1      6   1
# 2       11        1103                 1  110005400       1      1      6   3
# 3       11        1103                 1  110005400       1      1      6   4
# 4       11        1103                 1  110005400       1      1      6   5
# ...     ..         ...               ...        ...     ...    ...    ...  ..
# 478567  53        5306                 1  530025746      13      1     15  11
# 478568  53        5306                 1  530025746      13      1     16  13
# 478569  53        5306                 1  530025746      13      1     19   0
# 478570  53        5306                 1  530025746      13      1     19   7
# 478571  53        5306                 1  530025746      13      1     19  11
#
# ...

# %%
import pickle 

with open(datasetPicklePath + "/dfDespesaColetiva.pickle", "wb") as file:
            pickle.dump(dfDespesaColetiva, file)

dfDespesaColetiva.to_csv(datasetPath + "/dfDespesaColetiva.csv", encoding='utf-8', index=False, header=True)

# %%
# V9001: Código do produto
# V8000: Valor em reais
# V8000_DEFLA: Valor em reais corrigido pela inflação
# dfDespesaColetiva[["V9001", "V8000", "V8000_DEFLA"]]
# dfDespesaColetiva[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaColetiva["V9001"]=="6300101" ]
dfDespesaColetiva[["V9001", "V8000", "V8000_DEFLA"]]
# dfDespesaColetiva[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaColetiva["V9001"]=="C0001A" ]
# dfDespesaColetiva[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaColetiva["V9001"]=="2200101" ]
# dfDespesaIndividual["V9001"]
# Out:
#           V9001    V8000 V8000_DEFLA
# 0        600101   278.00      248.21
# 1        600201    45.00       48.79
# 2        600401   118.00      115.78
# 3        600501    80.00       80.00
# 4        600601   100.00      100.00
# ...         ...      ...         ...
# 478567  1501201   299.00      296.24
# 478568  1601401   125.00      128.57
# 478569  1900101  1050.00     1051.59
# 478570  1900801   140.00      140.21
# 478571  1901401   240.00      240.36
#
# [478572 rows x 3 columns]

# %%
# Individual
# V9001: Código do produto
# V8000: Valor em reais
# V8000_DEFLA: Valor em reais corrigido pela inflação
# dfDespesaColetiva[["V9001", "V8000", "V8000_DEFLA"]]
# dfDespesaColetiva[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaColetiva["V9001"]=="6300101" ] # Arrpz p[olido]
dfDespesaColetiva[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaColetiva["V9001"]=="8579026" ]
# dfDespesaColetiva[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaColetiva["V9001"]=="8000101" ]
# dfDespesaColetiva[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaColetiva["V9001"]=="2200101" ]
# dfDespesaColetiva["V9001"]
# Out:
# Empty DataFrame
# Columns: [V9001, V8000, V8000_DEFLA]
# Index: []

# %% [markdown]
# # Despesa Individual

# %%
wDespesaIndividual = [2,4,1,9,2,1,2,2,2,7,2,10,2,2,1,1,1,12,10,1,2,14,14,10,5]
                     # [2,4,1,9,2,1,2,2,2,7,2,10,2,2,1,1,1,12,10,1,2,14,14,10,5]

hDespesaIndividual = ['UF',
   'ESTRATO_POF',
   'TIPO_SITUACAO_REG',
   'COD_UPA',
   'NUM_DOM',
   'NUM_UC',
   'COD_INFORMANTE',
   'QUADRO',
   'SEQ',
   'V9001',
   'V9002',
   'V8000',
   'V9010',
   'V9011',
   'V9012',
   'V4104',
   'V4105',
   'DEFLATOR',
   'V8000_DEFLA',
   'COD_IMPUT_VALOR',
   'FATOR_ANUALIZACAO',
   'PESO',
   'PESO_FINAL',
   'RENDA_TOTAL',
   "V9004"]

dfDespesaIndividual = pd.read_fwf(f"{datasetPath}/despesa_Individual.txt", widths=wDespesaIndividual, index=False, header=None, dtype=str)
dfDespesaIndividual.columns = hDespesaIndividual

with open(datasetPicklePath + "/dfDespesaIndividual.pickle", "wb") as file:
            pickle.dump(dfDespesaIndividual, file)
            
dfDespesaIndividual.to_csv(datasetPath + "/despesaIndividual.csv", encoding='utf-8', index=False, header=True)
# dfDespesaIndividual.to_excel(datasetPath + "/despesaIndividual.xlsx", index=False, header=True)

# %%
dfDespesaIndividual[["V9001", "V8000", "V8000_DEFLA"]]
# Out:
#            V9001      V8000 V8000_DEFLA
# 0        2200101       7.00        7.00
# 1        2301401     100.00      105.06
# 2        2400101      25.00       25.33
# 3        2400101      25.00       25.33
# 4        2401901       6.00        6.13
# ...          ...        ...         ...
# 1836027  5000301    4600.00     4677.30
# 1836028  5100101  155000.00   156755.47
# 1836029  5100101  119000.00   120347.74
# 1836030  5100101   99000.00   100121.23
# 1836031  5100101   67000.00    67758.81
#
# [1836032 rows x 3 columns]

# %%
# Individual
# V9001: Código do produto
# V8000: Valor em reais
# V8000_DEFLA: Valor em reais corrigido pela inflação
dfDespesaIndividual[["V9001", "V8000", "V8000_DEFLA"]]
# dfDespesaIndividual[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaIndividual["V9001"]=="6300201" ] # Arrpz p[olido]
# dfDespesaIndividual[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaIndividual["V9001"]=="6300101" ]
# dfDespesaIndividual[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaIndividual["V9001"]=="8000101" ]
# dfDespesaIndividual[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaIndividual["V9001"]=="2200101" ]
# dfDespesaIndividual["V9001"]
# Out:
#            V9001      V8000 V8000_DEFLA
# 0        2200101       7.00        7.00
# 1        2301401     100.00      105.06
# 2        2400101      25.00       25.33
# 3        2400101      25.00       25.33
# 4        2401901       6.00        6.13
# ...          ...        ...         ...
# 1836027  5000301    4600.00     4677.30
# 1836028  5100101  155000.00   156755.47
# 1836029  5100101  119000.00   120347.74
# 1836030  5100101   99000.00   100121.23
# 1836031  5100101   67000.00    67758.81
#
# [1836032 rows x 3 columns]

# %%
from app.components.extract_data.extract_data import getDfConsumo
# Out:
# Loading basic data
# Loading basic dictionary
# Finish!

# %%
dfConsumo = getDfConsumo()

# %%
# dfConsumo[ ["V9001", "COD_TBCA"]][dfConsumo["V9001"]==6300101.0] # Arropz polido
# dfConsumo[ ["V9001", "COD_TBCA"]][dfConsumo["V9001"]==8581001.0] # Arropz polido
# dfConsumo[ ["V9001", "COD_TBCA"]][dfConsumo["COD_TBCA"]=="C0013A"] # ARROZ CRU
dfConsumo[ ["V9001", "COD_TBCA"]] 
# dfConsumo["V9001"].dtype
# "8000101.0"
# Out:
#            V9001 COD_TBCA
# 0        8000101   C0002A
# 1        7901602   C0008D
# 2        8501303   C0081H
# 3        6906602   C0007K
# 4        6300101   C0209A
# ...          ...      ...
# 1175372  8002301   C0027A
# 1175373  8000229   C0417A
# 1175374  8500921   C0395A
# 1175375  8300101   C0009H
# 1175376  8201004   C0145H
#
# [644610 rows x 2 columns]

# %%
v9001 = "8581001"
v9001 = "600601"

# %%
dfConsumo[ ["V9001", "COD_TBCA"]][dfConsumo["V9001"]==float(v9001)] # Arropz polido
# Out:
# Empty DataFrame
# Columns: [V9001, COD_TBCA]
# Index: []

# %%
dfDespesaColetiva[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaColetiva["V9001"]==v9001 ]
# Out:
#          V9001   V8000 V8000_DEFLA
# 4       600601  100.00      100.00
# 458     600601   50.00       50.00
# 478     600601  172.00      172.00
# 797     600601   59.00       59.00
# 973     600601  137.00      137.00
# ...        ...     ...         ...
# 477638  600601   70.00       70.00
# 478010  600601   25.00       25.00
# 478110  600601   70.00       70.00
# 478122  600601  120.00      120.00
# 478455  600601  460.00      460.00
#
# [5275 rows x 3 columns]

# %%
dfDespesaIndividual[["V9001", "V8000", "V8000_DEFLA"]][ dfDespesaIndividual["V9001"]==v9001 ]
# Out:
# Empty DataFrame
# Columns: [V9001, V8000, V8000_DEFLA]
# Index: []
