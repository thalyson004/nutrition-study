# %%
import sys
sys.path.append("..")

from extract_data.extract_data import * # Readind and initialization of the datasets
from pandas import DataFrame
from extract_data.dataframes.dictionaries.nutrients import nutrients
from extract_data.dataframes.get_nutrition import get_nutrients_dif

import numpy as np

# %%
dfConsumo
# Out:
#            UF  ESTRATO_POF  TIPO_SITUACAO_REG      COD_UPA  NUM_DOM  NUM_UC  \
# 0        11.0       1101.0                1.0  110000016.0      2.0     1.0
# 1        11.0       1101.0                1.0  110000016.0      2.0     1.0
# 2        11.0       1101.0                1.0  110000016.0      2.0     1.0
# 3        11.0       1101.0                1.0  110000016.0      2.0     1.0
# 4        11.0       1101.0                1.0  110000016.0      2.0     1.0
# ...       ...          ...                ...          ...      ...     ...
# 1175372  53.0       5301.0                1.0  530044198.0     12.0     1.0
# 1175373  53.0       5301.0                1.0  530044198.0     12.0     1.0
# 1175374  53.0       5301.0                1.0  530044198.0     12.0     1.0
# 1175375  53.0       5301.0                1.0  530044198.0     12.0     1.0
# 1175376  53.0       5301.0                1.0  530044198.0     12.0     1.0
#
# ...
