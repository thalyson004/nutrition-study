# %%
import sys
sys.path.append("../..")

from app.components.extract_data  import * # Readind and initialization of the datasets
from pandas import DataFrame
from app.components.extract_data.dataframes.dictionaries.nutrients import nutrients
from app.components.extract_data.dataframes.get_nutrition import get_nutrients, get_nutrients_dif

import numpy as np
# Out:
# Reading the datasets
# Creating person ID
# Removing unnecessary columns
# Convert codes into readable

# %%
dfConsumo.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Projetos\Doctorate\nutrition-study\notebooks\samples\001_get_nutrients_of_each_person.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/Projetos/Doctorate/nutrition-study/notebooks/samples/001_get_nutrients_of_each_person.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> dfConsumo.head()
#
# NameError: name 'dfConsumo' is not defined

# %%
## Get the dataframe with the sum of each nutrients consumed by each person
dfNutrients = get_nutrients(dfConsumo)
dfNutrients.head()
# Out:
#                      PESSOA  ENERGIA_KCAL     CHOTOT       PTN       LIP  \
# 0  110000016.0#1.0#12.0#2.0       1710.90  201.76700  93.79800  59.77300
# 1  110000016.0#1.0#12.0#3.0       1447.55  211.72850  66.35600  38.40600
# 2  110000016.0#1.0#13.0#1.0       1654.63  214.56008  72.97622  63.32802
# 3   110000016.0#1.0#2.0#1.0       1517.45  222.61650  62.84800  47.73160
# 4   110000016.0#1.0#2.0#2.0       1307.95  206.18650  42.30650  40.17660
#
#       FIBRA     COLEST    CALCIO       SODIO    POTASSIO  ...  RIBOFLAVINA  \
# 0   5.64800  345.50300  218.4860  1532.82000  1420.46300  ...      0.29400
# 1   6.69200  233.74300  181.5510  1124.75600  1470.25250  ...      0.23100
# 2  31.54542  184.57752  438.5491  2232.17768  3639.49704  ...      0.56212
# 3  26.33600   84.57700  211.9484  1679.27420  1827.59990  ...      1.11200
# 4  23.36950   46.93100  199.1539  1411.21920  1418.90640  ...      0.99450
#
# ...

# %%
## Person is the preprossed dfNutrients with more columns
## UF
## RENDA_TOTAL
## EER
## GENDER (SOON)
## AGE (SOON)
## HEIGHT (SOON)
## WEIGHT (SOON)
dfPerson.head()
# Out:
#                      PESSOA  ENERGIA_KCAL     CHOTOT       PTN       LIP  \
# 0  110000016.0#1.0#12.0#2.0       1710.90  201.76700  93.79800  59.77300
# 1  110000016.0#1.0#12.0#3.0       1447.55  211.72850  66.35600  38.40600
# 2  110000016.0#1.0#13.0#1.0       1654.63  214.56008  72.97622  63.32802
# 3   110000016.0#1.0#2.0#1.0       1517.45  222.61650  62.84800  47.73160
# 4   110000016.0#1.0#2.0#2.0       1307.95  206.18650  42.30650  40.17660
#
#       FIBRA     COLEST    CALCIO       SODIO    POTASSIO  ...    VITC  \
# 0   5.64800  345.50300  218.4860  1532.82000  1420.46300  ...  32.316
# 1   6.69200  233.74300  181.5510  1124.75600  1470.25250  ...  13.780
# 2  31.54542  184.57752  438.5491  2232.17768  3639.49704  ...  67.380
# 3  26.33600   84.57700  211.9484  1679.27420  1827.59990  ...   7.803
# 4  23.36950   46.93100  199.1539  1411.21920  1418.90640  ...   6.480
#
#    VITA_RAE    COBRE     FOLATO    FOSFORO     ZINCO    UF  RENDA_TOTAL  \
# ...

# %%
## DataFrame with the actual nutrition and the difference with optimal nutrition by nutrient
dfNutrientsDif = get_nutrients_dif(dfPerson)
dfNutrientsDif.head()
# Out:
#                      PESSOA  ENERGIA_KCAL     CHOTOT       PTN       LIP  \
# 0  110000016.0#1.0#12.0#2.0       1710.90  201.76700  93.79800  59.77300
# 1  110000016.0#1.0#12.0#3.0       1447.55  211.72850  66.35600  38.40600
# 2  110000016.0#1.0#13.0#1.0       1654.63  214.56008  72.97622  63.32802
# 3   110000016.0#1.0#2.0#1.0       1517.45  222.61650  62.84800  47.73160
# 4   110000016.0#1.0#2.0#2.0       1307.95  206.18650  42.30650  40.17660
#
#       FIBRA     COLEST    CALCIO       SODIO    POTASSIO  ...  \
# 0   5.64800  345.50300  218.4860  1532.82000  1420.46300  ...
# 1   6.69200  233.74300  181.5510  1124.75600  1470.25250  ...
# 2  31.54542  184.57752  438.5491  2232.17768  3639.49704  ...
# 3  26.33600   84.57700  211.9484  1679.27420  1827.59990  ...
# 4  23.36950   46.93100  199.1539  1411.21920  1418.90640  ...
#
#    RIBOFLAVINA_DIFF  NIACINA_DIFF  PIRIDOXAMINA_DIFF  COBALAMINA_DIFF  \
# 0          -0.70600      24.68300           -0.94700           -0.750
# ...
