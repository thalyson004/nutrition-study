# %%
import sys
sys.path.append("../..")

from app.components.basic_dataframes import * # Readind and initialization of the datasets

from pandas import DataFrame
# Out:
# Reading the datasets
# Finish!

# %%
dfConsumo.head() # All meals
# Out:
#      UF  ESTRATO_POF  TIPO_SITUACAO_REG      COD_UPA  NUM_DOM  NUM_UC
# 0  11.0       1101.0                1.0  110000016.0      2.0     1.0  \
# 1  11.0       1101.0                1.0  110000016.0      2.0     1.0
# 2  11.0       1101.0                1.0  110000016.0      2.0     1.0
# 3  11.0       1101.0                1.0  110000016.0      2.0     1.0
# 4  11.0       1101.0                1.0  110000016.0      2.0     1.0
#
#    COD_INFORMANTE  QUADRO  SEQ  V9005  ...   VITC    FOLATO         PESO
# 0             1.0    72.0  1.0    1.0  ...  0.000  104.6850  1316.609446  \
# 1             1.0    72.0  1.0    NaN  ...  0.000    0.1358  1316.609446
# 2             1.0    72.0  2.0    1.0  ...  0.000    5.0850  1316.609446
# 3             1.0    72.0  2.0    NaN  ...  0.000    0.0000  1316.609446
# 4             1.0    72.0  3.0    2.0  ...  0.405    2.4120  1316.609446
#
#     PESO_FINAL  RENDA_TOTAL       DIA_SEMANA  DIA_ATIPICO            id
# ...

# %%
from app.components.extract_data.dataframes.dictionaries.nutrients import nutrients
from app.components.extract_data.extract_data import get_meals_codes_list


mealNutrition:dict[str, dict] = {} # CODEA : {ZINCO:4, PTN:4... etc}

mealsCodes = dfMealCode
mealsCodesList = get_meals_codes_list()

mealsCodesList
for code in mealsCodesList:
    mealNutrition[code] = nutrients
    
print(mealNutrition)

dfConsumo

# print(nutrients)
# Out:
# {b'C0002A': {'ENERGIA_KCAL': 'Energy (kcal)', 'CHOTOT': 'Carbohydrates (g)', 'PTN': 'Protein (g)', 'LIP': 'Total fats (g)', 'FIBRA': 'Total fiber (g)', 'COLEST': 'Cholesterol (mg)', 'CALCIO': 'Calcium (mg)', 'SODIO': 'Sodium (mg)', 'POTASSIO': 'Potassium (mg)', 'FERRO': 'Iron (mg)', 'MAGNESIO': 'Magnesium (mg)', 'TIAMINA': 'Vitamin B1 (mg)', 'RIBOFLAVINA': 'Vitamin B2 (mg)', 'NIACINA': 'Niacin/B3 (mg)', 'PIRIDOXAMINA': 'Vitamin B6 (mg)', 'COBALAMINA': 'Vitamin B12', 'VITC': 'Vitamin C (mg)', 'VITA_RAE': 'Vitamin A (µg)', 'COBRE': 'Copper (mg)', 'FOLATO': 'Folate (µg)', 'FOSFORO': 'Phosphorus (mg)', 'ZINCO': 'Zinc (mg)'}, b'C0008D': {'ENERGIA_KCAL': 'Energy (kcal)', 'CHOTOT': 'Carbohydrates (g)', 'PTN': 'Protein (g)', 'LIP': 'Total fats (g)', 'FIBRA': 'Total fiber (g)', 'COLEST': 'Cholesterol (mg)', 'CALCIO': 'Calcium (mg)', 'SODIO': 'Sodium (mg)', 'POTASSIO': 'Potassium (mg)', 'FERRO': 'Iron (mg)', 'MAGNESIO': 'Magnesium (mg)', 'TIAMINA': 'Vitamin B1 (mg)', 'RIBOFLAVINA': 'Vitamin B2
# ...
