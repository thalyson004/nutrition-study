# %%
import sys
sys.path.append("../..")

from app.components.simple_types import *
# Out:
# Loading basic data
# Loading basic dictionary
# Finish!

# %%
state = State()
print(state)
# Out:
# State(data={'C0002A': 0, 'C0008D': 0, 'C0081H': 0, 'C0007K': 0, 'C0209A': 0, 'C0638F': 0, 'C0091T': 0, 'C0008U': 0, 'C0145H': 0, 'C0418A': 0, 'C0634F': 0, 'C0377B': 0, 'C0030H': 0, 'C0225A': 0, 'C0031D': 0, 'C0030L': 0, 'C0055A': 0, 'C0002D': 0, 'C0043A': 0, 'C0038C': 0, 'C0906B': 0, 'C0716F': 0, 'C0134C': 0, 'C0902B': 0, 'C0023C': 0, 'C0060K': 0, 'C0170A': 0, 'C0046K': 0, 'C0576F': 0, 'C0009H': 0, 'C0062H': 0, 'C0734F': 0, 'C0558B': 0, 'C0161C': 0, 'C0230F': 0, 'C0150B': 0, 'C0006C': 0, 'C0211A': 0, 'C0713F': 0, 'C0023J': 0, 'C0118B': 0, 'C0732F': 0, 'C0002C': 0, 'C0708F': 0, 'C0788B': 0, 'C0782B': 0, 'C0533F': 0, 'C0087B': 0, 'C0147C': 0, 'C0460A': 0, 'C0062K': 0, 'C0245F': 0, 'C0419A': 0, 'C0834A': 0, 'C0898F': 0, 'C0733F': 0, 'C0028J': 0, 'C0165A': 0, 'C0859F': 0, 'C0212A': 0, 'C0031H': 0, 'C0109C': 0, 'C0027C': 0, 'C0849B': 0, 'C0503F': 0, 'C0054G': 0, 'C0720F': 0, 'C0034G': 0, 'C0059G': 0, 'C0015H': 0, 'C0267A': 0, 'C0240A': 0, 'C0061G': 0, 'C0032H': 0, 'C0011H': 0, 'C0420A': 0
# ...

# %%
nutrition = state.nutrition()
print(nutrition)
# Out:
# Nutrition(data={'ENERGIA_KCAL': 0.0, 'CHOTOT': 0.0, 'PTN': 0.0, 'LIP': 0.0, 'FIBRA': 0.0, 'COLEST': 0.0, 'CALCIO': 0.0, 'SODIO': 0.0, 'POTASSIO': 0.0, 'FERRO': 0.0, 'MAGNESIO': 0.0, 'TIAMINA': 0.0, 'RIBOFLAVINA': 0.0, 'NIACINA': 0.0, 'PIRIDOXAMINA': 0.0, 'COBALAMINA': 0.0, 'VITC': 0.0, 'VITA_RAE': 0.0, 'COBRE': 0.0, 'FOLATO': 0.0, 'FOSFORO': 0.0, 'ZINCO': 0.0})

# %%
nutrition = Nutrition(state)
print(nutrition)
# Out:
# Nutrition(data={'ENERGIA_KCAL': 0.0, 'CHOTOT': 0.0, 'PTN': 0.0, 'LIP': 0.0, 'FIBRA': 0.0, 'COLEST': 0.0, 'CALCIO': 0.0, 'SODIO': 0.0, 'POTASSIO': 0.0, 'FERRO': 0.0, 'MAGNESIO': 0.0, 'TIAMINA': 0.0, 'RIBOFLAVINA': 0.0, 'NIACINA': 0.0, 'PIRIDOXAMINA': 0.0, 'COBALAMINA': 0.0, 'VITC': 0.0, 'VITA_RAE': 0.0, 'COBRE': 0.0, 'FOLATO': 0.0, 'FOSFORO': 0.0, 'ZINCO': 0.0})

# %%
state['C0002A'] += 10
state
# Out:
# State(data={'C0002A': 10, 'C0008D': 0, 'C0081H': 0, 'C0007K': 0, 'C0209A': 0, 'C0638F': 0, 'C0091T': 0, 'C0008U': 0, 'C0145H': 0, 'C0418A': 0, 'C0634F': 0, 'C0377B': 0, 'C0030H': 0, 'C0225A': 0, 'C0031D': 0, 'C0030L': 0, 'C0055A': 0, 'C0002D': 0, 'C0043A': 0, 'C0038C': 0, 'C0906B': 0, 'C0716F': 0, 'C0134C': 0, 'C0902B': 0, 'C0023C': 0, 'C0060K': 0, 'C0170A': 0, 'C0046K': 0, 'C0576F': 0, 'C0009H': 0, 'C0062H': 0, 'C0734F': 0, 'C0558B': 0, 'C0161C': 0, 'C0230F': 0, 'C0150B': 0, 'C0006C': 0, 'C0211A': 0, 'C0713F': 0, 'C0023J': 0, 'C0118B': 0, 'C0732F': 0, 'C0002C': 0, 'C0708F': 0, 'C0788B': 0, 'C0782B': 0, 'C0533F': 0, 'C0087B': 0, 'C0147C': 0, 'C0460A': 0, 'C0062K': 0, 'C0245F': 0, 'C0419A': 0, 'C0834A': 0, 'C0898F': 0, 'C0733F': 0, 'C0028J': 0, 'C0165A': 0, 'C0859F': 0, 'C0212A': 0, 'C0031H': 0, 'C0109C': 0, 'C0027C': 0, 'C0849B': 0, 'C0503F': 0, 'C0054G': 0, 'C0720F': 0, 'C0034G': 0, 'C0059G': 0, 'C0015H': 0, 'C0267A': 0, 'C0240A': 0, 'C0061G': 0, 'C0032H': 0, 'C0011H': 0, 'C0420A': 
# ...

# %%
nutrition = Nutrition(state)
print(nutrition)
# Out:
# Nutrition(data={'ENERGIA_KCAL': 30.0, 'CHOTOT': 6.164000000000001, 'PTN': 0.983, 'LIP': 0.212, 'FIBRA': 0.261, 'COLEST': 0.0, 'CALCIO': 1.4180000000000001, 'SODIO': 68.19, 'POTASSIO': 14.97, 'FERRO': 0.43300000000000005, 'MAGNESIO': 2.488, 'TIAMINA': 0.040999999999999995, 'RIBOFLAVINA': 0.07, 'NIACINA': 0.246, 'PIRIDOXAMINA': 0.063, 'COBALAMINA': 0.0, 'VITC': 0.0, 'VITA_RAE': 0.204, 'COBRE': 0.014, 'FOLATO': 14.955, 'FOSFORO': 9.975000000000001, 'ZINCO': 0.08199999999999999})

# %%
nutrition = state.nutrition()
print(nutrition)
# Out:
# Nutrition(data={'ENERGIA_KCAL': 30.0, 'CHOTOT': 6.164000000000001, 'PTN': 0.983, 'LIP': 0.212, 'FIBRA': 0.261, 'COLEST': 0.0, 'CALCIO': 1.4180000000000001, 'SODIO': 68.19, 'POTASSIO': 14.97, 'FERRO': 0.43300000000000005, 'MAGNESIO': 2.488, 'TIAMINA': 0.040999999999999995, 'RIBOFLAVINA': 0.07, 'NIACINA': 0.246, 'PIRIDOXAMINA': 0.063, 'COBALAMINA': 0.0, 'VITC': 0.0, 'VITA_RAE': 0.204, 'COBRE': 0.014, 'FOLATO': 14.955, 'FOSFORO': 9.975000000000001, 'ZINCO': 0.08199999999999999})

# %%
dictNutrition = Nutrition.getDictNutrition(state)
print(dictNutrition)
# Out:
# {'ENERGIA_KCAL': 30.0, 'CHOTOT': 6.164000000000001, 'PTN': 0.983, 'LIP': 0.212, 'FIBRA': 0.261, 'COLEST': 0.0, 'CALCIO': 1.4180000000000001, 'SODIO': 68.19, 'POTASSIO': 14.97, 'FERRO': 0.43300000000000005, 'MAGNESIO': 2.488, 'TIAMINA': 0.040999999999999995, 'RIBOFLAVINA': 0.07, 'NIACINA': 0.246, 'PIRIDOXAMINA': 0.063, 'COBALAMINA': 0.0, 'VITC': 0.0, 'VITA_RAE': 0.204, 'COBRE': 0.014, 'FOLATO': 14.955, 'FOSFORO': 9.975000000000001, 'ZINCO': 0.08199999999999999}

# %%
Nutrition.idealNutritionByEer(2022.16)
# Out:
# Nutrition(data={'ENERGIA_KCAL': 2022.16, 'CHOTOT': 1112.188, 'PTN': 303.324, 'LIP': -606.648, 'FIBRA': 0, 'COLEST': -300, 'CALCIO': 868, 'SODIO': 0, 'POTASSIO': 3510, 'FERRO': 6.8, 'MAGNESIO': 303, 'TIAMINA': 0.9, 'RIBOFLAVINA': 1, 'NIACINA': 11.5, 'PIRIDOXAMINA': 1.1, 'COBALAMINA': 2, 'VITC': 66.1, 'VITA_RAE': 560, 'COBRE': 0.7, 'FOLATO': 322, 'ZINCO': 8, 'FOSFORO': 649})

# %%
from app.components.basic_dataframes import dfPerson
dfPerson
# Out:
#                          PESSOA  ENERGIA_KCAL     CHOTOT        PTN
# 0      110000016.0#1.0#12.0#2.0      1710.900  201.76700   93.79800  \
# 1      110000016.0#1.0#12.0#3.0      1447.550  211.72850   66.35600
# 2      110000016.0#1.0#13.0#1.0      1654.630  214.56008   72.97622
# 3       110000016.0#1.0#2.0#1.0      1517.450  222.61650   62.84800
# 4       110000016.0#1.0#2.0#2.0      1307.950  206.18650   42.30650
# ...                         ...           ...        ...        ...
# 46159   530044198.0#1.0#3.0#1.0      3677.790  303.06040  157.57610
# 46160   530044198.0#1.0#3.0#3.0      1832.710  243.07530   63.33930
# 46161   530044198.0#1.0#3.0#4.0      2539.870  325.94240   97.02060
# 46162   530044198.0#1.0#9.0#1.0      1101.715  123.71514   68.93866
# 46163   530044198.0#1.0#9.0#2.0      1603.280  205.87150   57.80760
#
#              LIP     FIBRA     COLEST     CALCIO       SODIO    POTASSIO  ...
# ...

# %%
Nutrition.idealNutritionByPersonId(dfPerson.iloc[0]["PESSOA"])
# Out:
# Nutrition(data={'ENERGIA_KCAL': 2022.1599999999999, 'CHOTOT': 1112.188, 'PTN': 303.32399999999996, 'LIP': -606.6479999999999, 'FIBRA': 0, 'COLEST': -300, 'CALCIO': 868, 'SODIO': 0, 'POTASSIO': 3510, 'FERRO': 6.8, 'MAGNESIO': 303, 'TIAMINA': 0.9, 'RIBOFLAVINA': 1, 'NIACINA': 11.5, 'PIRIDOXAMINA': 1.1, 'COBALAMINA': 2, 'VITC': 66.1, 'VITA_RAE': 560, 'COBRE': 0.7, 'FOLATO': 322, 'ZINCO': 8, 'FOSFORO': 649})
