# %%
import sys
sys.path.append("../..")

# %%
import pandas

from pandas import DataFrame

# Import dictonaries and Types
from app.components.basic_dataframes import dictMealState, dfMealCode, dfMealState
from app.components.simple_types import Nutrition, State
from app.components.extract_data.extract_data import getDictPersonIdStrata

# Use simple function
from app.components.search.papa_search import papaSingleSeach, SearchResult
# Out:
# Loading basic data
# Loading basic dictionary
# Finish!

# %%
from app.components.extract_data.extract_data import getDfConsumo, getDfPersonAdultsFemale, getDfPersonAdultsMale, getDfPersonAdults, getDfPerson, getDictNutritionByMeal

dfPerson = getDfPerson()

# %%
dfPerson[["PESSOA", "AGE", "GENDER"]][ (dfPerson["AGE"]>=25) & (dfPerson["AGE"]<=65)]
# Out:
#                  PESSOA   AGE  GENDER
# 0      110000016#12#1#2  32.0  female
# 2      110000016#13#1#1  53.0  female
# 3       110000016#2#1#1  64.0    male
# 4       110000016#2#1#2  61.0  female
# 5       110000016#2#1#3  41.0    male
# ...                 ...   ...     ...
# 46155   530044198#2#1#1  50.0    male
# 46156   530044198#2#1#2  50.0  female
# 46159   530044198#3#1#1  50.0    male
# 46162   530044198#9#1#1  41.0  female
# 46163   530044198#9#1#2  52.0    male
#
# [28635 rows x 3 columns]

# %%
dfPerson = getDfPersonAdults()

# %%
dfPerson[["PESSOA", "AGE", "GENDER"]]
# Out:
#                  PESSOA   AGE  GENDER
# 0      110000016#12#1#2  32.0  female
# 2      110000016#13#1#1  53.0  female
# 5       110000016#2#1#3  41.0    male
# 6       110000016#7#1#1  37.0    male
# 7       110000016#7#1#2  36.0  female
# ...                 ...   ...     ...
# 46155   530044198#2#1#1  50.0    male
# 46156   530044198#2#1#2  50.0  female
# 46159   530044198#3#1#1  50.0    male
# 46162   530044198#9#1#1  41.0  female
# 46163   530044198#9#1#2  52.0    male
#
# [26119 rows x 3 columns]

# %%
getDfPersonAdultsFemale()
# Out:
#                  PESSOA  ENERGIA_KCAL     CHOTOT       PTN       LIP
# 0      110000016#12#1#2      1710.900  201.76700  93.79800  59.77300  \
# 2      110000016#13#1#1      1654.630  214.56008  72.97622  63.32802
# 7       110000016#7#1#2      1601.755  160.72095  63.35155  80.97520
# 10     110000584#10#1#1      1294.630  182.29050  54.85830  43.54400
# 11     110000584#11#1#2      1354.650  136.64350  18.44600   1.02000
# ...                 ...           ...        ...       ...       ...
# 46151   530042964#9#1#2       963.250  140.44500  47.83050  27.67450
# 46152   530042964#9#1#4      1431.435  243.05955  45.67230  36.72200
# 46153  530044198#11#1#1      1933.000  246.74050  68.43250  78.48950
# 46156   530044198#2#1#2       936.940  100.97490  40.55990  43.56496
# 46162   530044198#9#1#1      1101.715  123.71514  68.93866  40.62661
#
#           FIBRA     COLEST      CALCIO       SODIO    POTASSIO  ...
# 0       5.64800  345.50300   218.48600  1532.82000  1420.46300  ...  \
# 2      31.54542  184.57752   438.54910  2232.17768  3639.49704  ...
# 7      10.81480  189.86300   439.95825  2775.95890  1266.46715  ...
# 10     22.66770  414.55050   149.66890  1675.40860  2540.49120  ...
# 11      3.36000    0.00000   245.26200   176.36200  1338.86350  ...
# ...         ...        ...         ...         ...         ...  ...
# 46151  19.84350  584.59300   188.52950  1367.65500  1372.67550  ...
# 46152  26.53120  144.91765   423.07365  1593.43415  1825.06570  ...
# 46153  16.38900  166.55450  1449.83000  1956.29000  2313.64150  ...
# 46156  10.27240   99.13060   275.14004   885.92722  1387.08254  ...
# 46162  17.44411  498.41876   250.99770  1105.24014  1812.49727  ...
#
#           FOSFORO     ZINCO                                       UF
# 0       859.45900   6.04400               854700854700854686515200.0  \
# 2       978.20546   7.35082     6172839506172839782262224587849728.0
# 7       772.16155  11.09955             79365079365079368042807296.0
# 10      659.72360   6.62060             79365079365079368042807296.0
# 11      582.53000   0.45000                     1587301587301.571533
# ...           ...       ...                                      ...
# 46151   732.24750   6.43950              4118104118104117693382656.0
# 46152   769.69805   4.87425                44612794612794613825536.0
# 46153  1219.44800  11.88900    29741863075196406820470388141588480.0
# 46156   569.21022   9.30190  2817650186071238622440694781392715776.0
# 46162   803.16223   6.91746  2817650186071238622440694781392715776.0
#
#        RENDA_TOTAL  ESTRATO_POF      EER   AGE  HEIGHT  WEIGHT  GENDER
# 0          4353.51       1101.0  2022.16  32.0   151.0    57.0  female
# 2          1367.63       1101.0  2003.41  53.0   168.0    66.0  female
# 7          6253.24       1101.0  2008.56  36.0   145.0    58.0  female
# 10         4140.14       1101.0  2416.82  46.0   158.0    92.0  female
# 11         2047.99       1101.0  2274.66  30.0   172.0    74.0  female
# ...            ...          ...      ...   ...     ...     ...     ...
# 46151      8540.58       5305.0  1898.66  58.0   140.0    61.0  female
# 46152      8540.58       5305.0  1993.42  26.0   166.0    52.0  female
# 46153      1569.03       5301.0  1958.21  25.0   157.0    49.0  female
# 46156     24739.80       5301.0  2290.90  50.0   164.0    85.0  female
# 46162     31051.45       5301.0  2367.13  41.0   163.0    86.0  female
#
# [14393 rows x 31 columns]

# %%
getDfPersonAdultsMale()
# Out:
#                  PESSOA  ENERGIA_KCAL     CHOTOT        PTN        LIP
# 5       110000016#2#1#3      1404.550  194.78750   90.52300   35.89260  \
# 6       110000016#7#1#1      2130.860  207.80540  102.85660  101.97780
# 15      110000602#2#1#1      2130.140  183.96150  134.59940  100.89730
# 16      110000602#5#1#1      2558.760  387.23690   79.27935   82.22825
# 19      110000602#8#1#2      3283.050  454.81350  163.40950   95.31000
# ...                 ...           ...        ...        ...        ...
# 46149   530042964#5#1#3      2059.050  202.67450  170.27200   69.85900
# 46154  530044198#12#1#1      1445.495  168.79888   54.55089   40.15098
# 46155   530044198#2#1#1      1657.240  260.90850   63.77200   43.41470
# 46159   530044198#3#1#1      3677.790  303.06040  157.57610  114.32300
# 46163   530044198#9#1#2      1603.280  205.87150   57.80760   64.33320
#
#           FIBRA     COLEST      CALCIO       SODIO    POTASSIO  ...
# 5      29.46900  122.22300   219.59740  2623.22120  2241.43290  ...  \
# 6      14.08460  373.53600   776.74560  3454.54460  1879.41840  ...
# 15     26.84010  550.94000   281.01810  1898.28000  2865.23570  ...
# 16     23.61410  374.62690   502.63225  2516.60945  2151.13825  ...
# 19     25.54200  452.51200   190.27850  5001.69700  2088.16700  ...
# ...         ...        ...         ...         ...         ...  ...
# 46149  31.73200  739.49900  1083.96000  4101.99800  3324.00650  ...
# 46154   8.06877  140.60187   747.06229  1624.95720  1355.24815  ...
# 46155  15.39380  139.47460   732.66200  1693.04670  2207.21150  ...
# 46159  15.86950  418.80350  1050.78490  3898.09930  3238.61370  ...
# 46163  15.99250  324.06950   642.55610  2833.04010  2003.86460  ...
#
#           FOSFORO     ZINCO                                        UF
# 5       989.77520  16.71200                     1111111111111111040.0  \
# 6      1262.93440  18.83460            7407407407407406813548642304.0
# 15     1270.08350  14.92410                       138888888888888.875
# 16     1104.55710   8.74775  55555555555555554304894346364463349760.0
# 19     1548.85900  13.09450              79365079365079368042807296.0
# ...           ...       ...                                       ...
# 46149  1967.46700  18.55000     29741863075196406820470388141588480.0
# 46154   907.15997   9.23614                       59483726150392816.0
# 46155   950.63140  12.44870       314913844325609041368517089165312.0
# 46159  2141.30100  13.26930       314913844325609041368517089165312.0
# 46163   961.63530   8.79630                     5353535353535353856.0
#
#        RENDA_TOTAL  ESTRATO_POF       EER   AGE  HEIGHT  WEIGHT  GENDER
# 5          3855.34       1101.0  2989.870  41.0   180.0    80.0    male
# 6          6253.24       1101.0  2932.530  37.0   168.0    76.0    male
# 15         1918.01       1107.0  2756.185  53.0   175.0    75.0    male
# 16         5772.36       1107.0  2851.725  58.0   180.0    81.0    male
# 19         4122.03       1107.0  3347.765  36.0   170.0    93.0    male
# ...            ...          ...       ...   ...     ...     ...     ...
# 46149      7830.60       5305.0  2588.810  33.0   170.0    60.0    male
# 46154       672.99       5301.0  2712.780  25.0   169.0    62.0    male
# 46155     24739.80       5301.0  2999.560  50.0   174.0    84.0    male
# 46159     35197.60       5301.0  3810.970  50.0   185.0   118.0    male
# 46163     31051.45       5301.0  2503.200  52.0   163.0    64.0    male
#
# [11726 rows x 31 columns]

# %%
dfPerson[["PESSOA", "AGE", "GENDER"]][ (dfPerson["AGE"]==25) & (dfPerson["GENDER"]=="male") ]
# Out:
#                  PESSOA   AGE GENDER
# 147    110004584#15#1#1  25.0   male
# 355     110010188#3#1#4  25.0   male
# 382     110012387#6#1#3  25.0   male
# 730     110021380#9#1#1  25.0   male
# 741     110021533#5#1#1  25.0   male
# ...                 ...   ...    ...
# 45558   530016827#5#1#2  25.0   male
# 45757   530026906#6#1#3  25.0   male
# 45935  530034389#10#1#3  25.0   male
# 46058   530039445#7#1#4  25.0   male
# 46154  530044198#12#1#1  25.0   male
#
# [339 rows x 3 columns]

# %%
dfPerson[["PESSOA", "AGE", "GENDER"]][ (dfPerson["AGE"]==60) & (dfPerson["GENDER"]=="male") ]
# Out:
#                  PESSOA   AGE GENDER
# 46     110001240#13#1#1  60.0   male
# 69     110002041#11#1#2  60.0   male
# 285     110007280#9#1#1  60.0   male
# 675    110020167#10#1#2  60.0   male
# 735    110021533#16#1#1  60.0   male
# ...                 ...   ...    ...
# 45277   530007397#4#1#2  60.0   male
# 45569  530019192#13#1#1  60.0   male
# 45770  530027874#12#1#1  60.0   male
# 45829  530030018#10#1#1  60.0   male
# 46070  530040428#12#1#2  60.0   male
#
# [252 rows x 3 columns]
