# %% [markdown]
# ## sprint 01
#
# - *Begin: 28/11/2022*
# - *Deadline: 09/12/2022*
#
# Main goal: To understand the related works and build initial scripts that explore the dataset, show nutritions of each person and compare with right nutrition.

# %%
from extract_data import * # Readind and initialization of the datasets
from pandas import DataFrame
from dictionaries.nutrients import nutrients
from dataframes.get_nutrition import get_nutrients_dif
import numpy as np

# %%
from calculations.factors import calc_eer
calc_eer(
    age=30,
    height=185,
    weight=105,
    activity="active",
    gender="male",
    )
# Out:
# 3691.3250000000003

# %% [markdown]
# ## Extract data

# %%
# age
# gender
# weight
# height

# %%
dfPerson.keys()
# Out:
# Index(['PESSOA', 'ENERGIA_KCAL', 'CHOTOT', 'PTN', 'LIP', 'FIBRA', 'COLEST',
#        'CALCIO', 'SODIO', 'POTASSIO', 'FERRO', 'MAGNESIO', 'TIAMINA',
#        'RIBOFLAVINA', 'NIACINA', 'PIRIDOXAMINA', 'COBALAMINA', 'VITC',
#        'VITA_RAE', 'COBRE', 'FOLATO', 'FOSFORO', 'ZINCO', 'UF', 'RENDA_TOTAL',
#        'EER'],
#       dtype='object')

# %%
dfPerson
# Out:
#                          PESSOA  ENERGIA_KCAL     CHOTOT        PTN  \
# 0      110000016.0#1.0#12.0#2.0      1710.900  201.76700   93.79800
# 1      110000016.0#1.0#12.0#3.0      1447.550  211.72850   66.35600
# 2      110000016.0#1.0#13.0#1.0      1654.630  214.56008   72.97622
# 3       110000016.0#1.0#2.0#1.0      1517.450  222.61650   62.84800
# 4       110000016.0#1.0#2.0#2.0      1307.950  206.18650   42.30650
# ...                         ...           ...        ...        ...
# 46159   530044198.0#1.0#3.0#1.0      3677.790  303.06040  157.57610
# 46160   530044198.0#1.0#3.0#3.0      1832.710  243.07530   63.33930
# 46161   530044198.0#1.0#3.0#4.0      2539.870  325.94240   97.02060
# 46162   530044198.0#1.0#9.0#1.0      1101.715  123.71514   68.93866
# 46163   530044198.0#1.0#9.0#2.0      1603.280  205.87150   57.80760
#
#              LIP     FIBRA     COLEST     CALCIO       SODIO    POTASSIO  ...  \
# ...

# %% [markdown]
# ## TEST

# %%
dfPerson
# Out:
#                          PESSOA  ENERGIA_KCAL     CHOTOT        PTN  \
# 0      110000016.0#1.0#12.0#2.0      1710.900  201.76700   93.79800
# 1      110000016.0#1.0#12.0#3.0      1447.550  211.72850   66.35600
# 2      110000016.0#1.0#13.0#1.0      1654.630  214.56008   72.97622
# 3       110000016.0#1.0#2.0#1.0      1517.450  222.61650   62.84800
# 4       110000016.0#1.0#2.0#2.0      1307.950  206.18650   42.30650
# ...                         ...           ...        ...        ...
# 46159   530044198.0#1.0#3.0#1.0      3677.790  303.06040  157.57610
# 46160   530044198.0#1.0#3.0#3.0      1832.710  243.07530   63.33930
# 46161   530044198.0#1.0#3.0#4.0      2539.870  325.94240   97.02060
# 46162   530044198.0#1.0#9.0#1.0      1101.715  123.71514   68.93866
# 46163   530044198.0#1.0#9.0#2.0      1603.280  205.87150   57.80760
#
#              LIP     FIBRA     COLEST     CALCIO       SODIO    POTASSIO  ...  \
# ...

# %%
get_nutrients_dif(dfPerson)
# Out:
#                          PESSOA  ENERGIA_KCAL     CHOTOT        PTN  \
# 0      110000016.0#1.0#12.0#2.0      1710.900  201.76700   93.79800
# 1      110000016.0#1.0#12.0#3.0      1447.550  211.72850   66.35600
# 2      110000016.0#1.0#13.0#1.0      1654.630  214.56008   72.97622
# 3       110000016.0#1.0#2.0#1.0      1517.450  222.61650   62.84800
# 4       110000016.0#1.0#2.0#2.0      1307.950  206.18650   42.30650
# ...                         ...           ...        ...        ...
# 46159   530044198.0#1.0#3.0#1.0      3677.790  303.06040  157.57610
# 46160   530044198.0#1.0#3.0#3.0      1832.710  243.07530   63.33930
# 46161   530044198.0#1.0#3.0#4.0      2539.870  325.94240   97.02060
# 46162   530044198.0#1.0#9.0#1.0      1101.715  123.71514   68.93866
# 46163   530044198.0#1.0#9.0#2.0      1603.280  205.87150   57.80760
#
#              LIP     FIBRA     COLEST     CALCIO       SODIO    POTASSIO  ...  \
# ...
